# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# %%
directory = os.fsencode('../../data/data_out/')
X = np.zeros((1,65))
y = np.empty(1)
i = 0
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename != 'No_target_out.txt' and filename.endswith('1_out_doppler_only.txt'):
        path = os.path.join(os.fsdecode(directory), filename)
        print(path)                    
        data = pd.read_csv(path, sep='\t', header=None)
        print(data.values[:,:].shape)
        X = np.append(X,data.values[:,:], axis=0)
        y = np.append(y,i + np.zeros((data.shape[0],1)))
        i += 1
        plt.plot(data.values[:,:-1].T)
        plt.show()
X = X[1:,:]#/max(np.amax(dataset, axis = 0))
y = y[1:]

### Normalization

#Doppler
range_max = np.max(X[:,:63])
range_min = np.min(X[:,:63])
print(range_max)
print(range_min)
X[:,:63] = (X[:,:63] - range_min)/(range_max - range_min)

#distance
dist_max = np.max(X[:,-1])
dist_min = np.min(X[:,-1])
print(dist_max)
print(dist_min)
X[:,-1] = (X[:,-1] -dist_min)/(dist_max - dist_min)
# Out:
# ../data_out/biking_mixed_128_test_1_out_doppler_only.txt
# (574, 65)
# ../data_out/walking_mixed_128_test_1_out_doppler_only.txt
# (460, 65)
# 433.6366236705676
# 0.0070288574129629
# 28.21442366850212
# 0.8469570187424857

# %% [raw]
# The dataset contains 2 information: the first is a slice of the spectrum around the peak, the second (which is the last column) contains the distance at which the peak happens.

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.70, test_size=0.30, random_state=100)
X_train = X
y_train = y

# %%
X = np.zeros((1,65))
y = np.empty(1)
i = 0
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename != 'No_target_out.txt' and filename.endswith('2_out_doppler_only.txt'):
        path = os.path.join(os.fsdecode(directory), filename)
        print(path)                    
        data = pd.read_csv(path, sep='\t', header=None)
        print(data.values[:,:].shape)
        X = np.append(X,data.values[:,:], axis=0)
        y = np.append(y,i + np.zeros((data.shape[0],1)))
        i += 1
        plt.plot(data.values[:,:-1].T)
        plt.show()
X = X[1:,:]#/max(np.amax(dataset, axis = 0))
y = y[1:]

### Normalization

#Doppler
X[:,:63] = (X[:,:63] - range_min)/(range_max - range_min)

#distance
X[:,-1] = (X[:,-1] -dist_min)/(dist_max - dist_min)
# Out:
# ../data_out/biking_mixed_128_test_2_out_doppler_only.txt
# (451, 65)
# ../data_out/walking_mixed_128_test_2_out_doppler_only.txt
# (515, 65)

# %%
X_test = X
y_test = y

# %%
svc = SVC(random_state=0)

param_grid = [{'kernel': ['rbf'], 'gamma': [1, 1e-1, 1e-2, 1e-3],
                     'C': [1, 10, 100, 1000, 10000]}]

search = GridSearchCV(
    estimator=svc, param_grid=param_grid,
    scoring='accuracy'
)
search.fit(X_train, y_train)
print("Best parameters set found on development set:")
print(search.best_params_)
y_pred = search.predict(X_test)
# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Best parameters set found on development set:
# {'C': 10000, 'gamma': 0.1, 'kernel': 'rbf'}
# Accuracy: 0.7898550724637681

# %%
from sklearn import linear_model
reg = linear_model.RidgeClassifierCV(alphas=np.logspace(-6, 6, 13))
reg.fit(X_train, y_train)
print(reg.alpha_)
y_pred = reg.predict(X_test)
# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.001
# Accuracy: 0.717391304347826

# %% [raw]
# import xgboost as xgb
#
# dtrain = xgb.DMatrix(X_train, label=y_train)
# dtest = xgb.DMatrix(X_test, label=y_test)
#
# clf = xgb.XGBClassifier()
# parameters = {
#      "eta"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
#      "max_depth"        : [ 3, 4, 5],
#      "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
#      "objective": ["binary:logistic"]
#      }
#
#
# grid = GridSearchCV(clf,
#                     parameters, n_jobs=4,
#                     scoring="accuracy",
#                     cv=5)
#
# grid.fit(X_train, y_train)
#
# y_pred = grid.predict(X_test)
# predictions = [round(value) for value in y_pred]
#
# accuracy = metrics.accuracy_score(y_test, predictions)
# print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %% [raw]
# grid.best_params_

# %% [raw]
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.80, test_size=0.20, random_state=101)

# %% [raw]
# rbf = OneVsRestClassifier(SVC(kernel='rbf', gamma=0.01, C=100))
# rbf.fit(X_train, y_train)
# y_pred = rbf.predict(X_test)

# %% [raw]
# # Model Accuracy: how often is the classifier correct?
# print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %% [raw]
# max_value = max(np.amax(dataset, axis = 0))

# %% [raw]
# #np.argmax(dataset[:,:-1], axis = 1)

# %%
y_pred = search.predict(X_test)

# %%
y_pred.shape
# Out:
# (966,)

# %%
# Model Accuracy: how often is the classifier correct?
print("Accuracy on ALL DATASET:",metrics.accuracy_score(y_pred, y))
# Out:
# Accuracy on ALL DATASET: 0.7898550724637681

# %%
chirps = y_pred.shape[0]
fig, ax = plt.subplots(2,1)
ax[0].plot(y_pred[:chirps])
ax[0].plot(y_test[:chirps])
ax[1].plot(X[:chirps,-1].T)

# %%
consec_frames = 20
total_frames = X.shape[0]//consec_frames
accuracy = 0

frame_prediction_array = np.zeros(total_frames)
frame_truth = np.zeros(total_frames)

for i in range(total_frames):
    
    frame_pred = np.sum(search.predict(X[i*consec_frames:(i+1)*consec_frames,:]))
    answer = 0
    if(frame_pred > consec_frames//2):
        answer = 1
    frame_prediction_array[i] = frame_pred
    frame_truth[i] = y[i*consec_frames]

    
fig, ax = plt.subplots(3,1)
ax[0].plot(frame_prediction_array)
ax[1].plot(np.round(frame_prediction_array/consec_frames))
ax[2].plot(frame_truth)
